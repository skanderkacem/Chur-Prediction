# %%
from IPython.display import display, HTML

display(HTML('''
    <style>
        body {
            font-family: 'Arial', sans-serif;
            background-color: #f0f2f5;
            margin: 0;
            padding: 0;
        }

        .title-container {
            display: flex;
            justify-content: center;
            align-items: center;
            height: 100vh;
            background: linear-gradient(135deg, #00aaff, #0077cc);
            background-size: 400% 400%;
            animation: gradient 6s ease infinite;
        }

        @keyframes gradient {
            0% { background-position: 0% 50%; }
            50% { background-position: 100% 50%; }
            100% { background-position: 0% 50%; }
        }

        h1 {
            font-size: 3.5em;
            font-weight: 700;
            color: #ffffff;
            text-align: center;
            letter-spacing: 2px;
            text-shadow: 2px 2px 10px rgba(0, 0, 0, 0.5);
            margin: 0;
            padding: 20px;
            border-radius: 15px;
            background: rgba(255, 255, 255, 0.15);
            box-shadow: 0 4px 15px rgba(0, 0, 0, 0.3);
        }

        h1 span {
            color: #f39c12;
        }
    </style>
    <div class="title-container">
        <h1>Predicting Customer <span>Churn</span>: A Comprehensive Approach Using Machine Learning</h1>
    </div>
'''))
# Out:
#     <style>
#         body {
#             font-family: 'Arial', sans-serif;
#             background-color: #f0f2f5;
#             margin: 0;
#             padding: 0;
#         }
#
#         .title-container {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             background: linear-gradient(135deg, #00aaff, #0077cc);
#             background-size: 400% 400%;
#             animation: gradient 6s ease infinite;
#         }
#
#         @keyframes gradient {
#             0% { background-position: 0% 50%; }
#             50% { background-position: 100% 50%; }
#             100% { background-position: 0% 50%; }
#         }
#
#         h1 {
#             font-size: 3.5em;
#             font-weight: 700;
#             color: #ffffff;
#             text-align: center;
#             letter-spacing: 2px;
#             text-shadow: 2px 2px 10px rgba(0, 0, 0, 0.5);
#             margin: 0;
# ...

# %% [markdown]
# **Our project follows the CRISP-DM methodology, a structured approach to data science that includes understanding the business problem of customer churn, analyzing and preparing telecom data, building predictive machine learning models, evaluating their performance, and deploying actionable solutions to improve customer retention strategies.**

# %% [markdown]
# **<font color=#f39c12 ><h1>
#   🤔 I-Business Undrestanding </p><h1>**

# %% [markdown]
# **<font color=#3498db ><h3>
# 1.Introduction to the Business Problem </p><h3>**

# %% [markdown]
# **In the competitive telecommunications industry, retaining customers is a priority because acquiring new ones is far more costly than keeping existing ones. Customer churn (attrition) occurs when a customer stops using the services provided by the company, impacting:**
#
#
# 1.   **Revenue:** Churn leads to direct revenue loss.
# 2.   **Operational efficiency:** High churn rates increase marketing costs to acquire replacements.
# 3.  **Customer experience:** Poor service satisfaction leads to churn and impacts brand reputation.
#
# **Key business questions:**
#
#
# *   How can we accurately identify customers at risk of churn?
# *   What actionable insights can we derive from the data to reduce churn effectively?
#
# **=>This project aims to build machine learning models that predict churn and explain the factors influencing it to inform better retention strategies.**

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# **<font color=#3498db ><h3>
# 2.Data Science Objectives (DSOs) and Their Transformation into Business Objectives (BOs) </p><h3>**

# %% [markdown]
# **DSO 1: "Implementing machine learning techniques for customer retention and churn prediction in telecommunications"**
#
#
# *   **DSO1 Objective** :Develop a machine learning model to predict churn and guide retention strategies effectively.
# *   **Business Objective 1**:Implement a churn prediction system capable of prioritizing customers at high risk of leaving.
#
# **DSO 2: "Explaining customer churn prediction in telecom industry using tabular machine learning models"**
#
#
# *   **DSO2 Objective** :Provide explainable insights into the factors driving churn using tools like SHAP to make machine learning models transparent and actionable.
# *   **Business Objective 2**:Provide actionable insights into the key drivers of customer churn by leveraging explainable machine learning techniques.
#
#
#
# **DSO 3: "Customer churn prediction in telecom sector using machine learning techniques"**
#
#
# *  **DSO3 Objective** :Optimize the performance, accuracy, and reliability of machine learning models for churn prediction to achieve scalable and consistent results.
# *  **Business Objective 3**:Analyze customer retention trends to identify key drivers of churn, informing retention strategies.
#
#
# ---
#
#
#
# ---

# %% [markdown]
# **<font color=#3498db ><h3>
# 3.Dataset Overview and Column Descriptions </p><h3>**

# %% [markdown]
# **The dataset contains customer-related features from the telecommunications sector. These columns will help in identifying churn and explaining the reasons behind it.**
#
# **Customer Profile:**
# 1.   **Account length:**
#
# *   Definition: Number of days the customer has been subscribed to the service.
#
# *   Importance: Long-term customers are often more loyal, but a sudden churn among them may indicate dissatisfaction.
#
# 2.   **Area code:**
#
# *   Definition:Regional code of the customer's phone number.
#
# *   Importance:Regional trends may reveal geographical patterns in churn behavior.
#
# **Service Plans and Usage:**
# 3.   **International plan:**
#
# *   Definition:Whether the customer has subscribed to an international calling plan (Yes/No).
#
# *   Importance:Customers with specific plans may churn if these services no longer meet their needs.
# 4.   **Voice mail plan:**
#
# *   Definition:Whether the customer has subscribed to a voicemail plan (Yes/No).
#
# *   Importance:Usage of optional features often indicates customer engagement and satisfaction.
# 5.   **Number vmail messages:**
#
# *   Definition:Number of voicemail messages recorded.
#
# *   Importance:Indicates usage patterns of advanced services.
#
# 6.   **Total day minutes / calls / charge:**
#
# *   Definition:Total duration, number of calls, and costs during the daytime.
#
# *   Importance: High or low call usage may indicate customer engagement or dissatisfaction.
# 7.   **Total eve minutes / calls / charge:**
#
# *   Definition:Evening call activity and costs.
#
# *   Importance: Usage trends across time periods can indicate satisfaction or disengagement.
# 8.   **Total night  minutes / calls / charge:**
#
# *   Definition:Nighttime call activity and costs.
#
# *   Importance: Usage trends across time periods can indicate satisfaction or disengagement.
# 9.   **Total intl minutes / calls / charge:**
#
# *   Definition:International call activity and costs.
#
# *   Importance: High costs might cause customers to churn.
#
# **Customer Service Interactions:**
# 10.   **Customer service calls:**
#
# *   Definition:Number of times the customer contacted customer service.
#
# *   Importance: Frequent calls often signal dissatisfaction, a strong churn indicator.
#
# **Target Column:**
# 11.   **Churn:**
#
# *   Definition:Whether the customer has churned (True = Yes, False = No).
#
# *   Importance: This is the column we aim to predict.

# %% [markdown]
# **<font color=#f39c12 ><h1>
#  🔍 II-Data Undrestanding </p><h1>**

# %%
pip install tensorflow
# Out:
#   Cell In[277], line 1
#     pip install tensorflow
#         ^
# SyntaxError: invalid syntax

# %%
pip install xgboost

# %%
pip install imbalanced-learn

# %%
pip install shap

# %%
pip install scipy

# %%
# !pip install scikeras

# %% [markdown]
# **<font color=#3498db ><h3>
# Importing Data </p><h3>**

# %%
import pandas as pd
import os

def load_data (file_name):
    csv_path = os.path.join("Data", file_name)
    return pd.read_csv(csv_path)

train_set = load_data("churn-bigml-80.csv")
test_set = load_data("churn-bigml-20.csv")

# %%
# Join the train and test datasets for the data understanding

Data = pd.concat([train_set, test_set], ignore_index=True)
Data

# %% [markdown]
# **<font color=#3498db ><h3>
# Exploring the data </p><h3>**

# %%
Data.head(10)

# %%
Data.shape

# %% [markdown]
# ------
# The data counts 20 Features with 3333 Instances

# %%
Data.info()

# %%
Data.dtypes.value_counts()

# %% [markdown]
# -------
# We have 20 Variables with 8 Integer, 8 Float, 3 String and 1 boolean. And we don't have missing values.

# %%
Data.describe()

# %% [markdown]
# **<font color=#3498db ><h3>
# Visualisation </p><h3>**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# plotting numerical data in a histogram where x-axis represent the the value ranges and the y-axis the number of instances in each range
Data.select_dtypes(include=['number']).hist(bins=30, figsize=(20, 15))
plt.show()

# %% [markdown]
# ### Interpretations:
# - We can see that the attributes have different scales. we need feature scaling
# - Most of the feautures have symetrical histograms, the mean and the median are very close, except some of them are skewed like (Number vmail messages, Area code, Total intl calls, Customer service calls).

# %%
# Plotting Categorical data in a bar plot
fig = plt.figure(figsize=(15, 10))

cat_columns = list(Data.select_dtypes(exclude=['number']))

for i in enumerate(cat_columns):
    count = Data[i[1]].value_counts()
    plt.subplot(2, 2, i[0] + 1)
    plt.bar(count.index, count.values)
    plt.xlabel(i[1])
    plt.ylabel('Count')
    plt.title(f'Counts of {i[1]}', fontsize=15)

fig.tight_layout(pad=3.0)
plt.show()

# %%
# Boxplot
def plot_boxplot(data):
    fig = plt.figure(figsize=(15, 30))

    num_columns = list(data.select_dtypes(include=['number']).columns)
    num_columns.remove('Area code')

    for i in enumerate(num_columns):
        plt.subplot(5, 4, i[0] + 1)
        sns.boxplot(y=i[1], data=data)
        plt.title(f'Box plot for the {i[1]} feature:', fontsize=10)

    fig.tight_layout(pad=3.0)
    plt.show()

plot_boxplot(Data)

# %% [markdown]
# ### Interpretation:
# We can see that the dataset have outliers.

# %%
# Density Plot (KDE)
fig = plt.figure(figsize=(15, 30))

num_columns = list(Data.select_dtypes(include=['number']).columns)
num_columns.remove('Area code')

for i in enumerate(num_columns):
    plt.subplot(5, 4, i[0] + 1)
    sns.kdeplot(Data[i[1]])
    plt.title(f'KDE plot for the {i[1]} feature:', fontsize=10)
    plt.xlabel(i[1])
    plt.ylabel('Density')

fig.tight_layout(pad=3.0)
plt.show()

# %%
# Corrolation Heatmap
def plot_corr_map(data):
    plt.figure(figsize=(12, 8))
    sns.heatmap(data.select_dtypes(include=['number']).corr(), annot=True, cmap='coolwarm')
    plt.title("Correlation Heatmap")
    plt.show()

plot_corr_map(Data)

# %% [markdown]
# ### Interpretation:
# From the Corrolation Map we can see that some feautures are fully corrolated with each other wich means that maybe it is the same feature or that they act the same way, So we need to either drop some features or fuse them into one feature like (Total day minutes and Total day charge).

# %% [markdown]
# **<font color=#f39c12 ><h1>
#  🧹 III-Data Preparation </p><h1>**

# %% [markdown]
# **<font color=#3498db ><h2>
# 1- Data Cleaning </p><h2>**

# %% [markdown]
# ### Drop duplicate columns:

# %%
# Wrapper class that drops the unneaded columns

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import LabelEncoder

class DropColumnTransformer(BaseEstimator, TransformerMixin):

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_transformed = X.copy()
        columns_to_drop = ['Total day minutes', 'Total eve minutes', 'Total night minutes', 'Total intl minutes']
        if all(col in X.columns for col in columns_to_drop):
            X_transformed = X.drop(['Total day minutes', 'Total eve minutes', 'Total night minutes', 'Total intl minutes'], axis=1)

        return X_transformed

# %% [markdown]
# ### Handle outliers:

# %% [markdown]
# ### Inter-Quartile-Range method

# %%
Data.info()

# %%
# Wrapper class that handles outliers

from sklearn.base import BaseEstimator, TransformerMixin

class HandleOutliersTransformer(BaseEstimator, TransformerMixin):

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_transformed = X.copy()
        num_columns = list(X_transformed.select_dtypes(include=['number']).columns)
        to_not_remove = {'Account length', 'Customer service calls', 'Area code'}
        num_columns = [item for item in num_columns if item not in to_not_remove]
        for column in num_columns:
            Q1 = X[column].quantile(0.25)
            Q3 = X[column].quantile(0.75)
            IQR = Q3 - Q1
            lower_fence = Q1 - 1.5 * IQR
            upper_fence = Q3 + 1.5 * IQR

            X_transformed = X_transformed[(X_transformed[column] >= lower_fence) & (X_transformed[column] <= upper_fence)]
            X_transformed = X_transformed.reset_index(drop=True)

        return X_transformed

# %% [markdown]
# **<font color=#3498db ><h2>
# 2- Data Transformation</p><h2>**

# %% [markdown]
# ### Label Encoder

# %%
# Wrapper class that transforms State and churn features using LabelEncoder

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import LabelEncoder
import numpy as np

class TransformLabelMethod(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.encoder_dict = {}

    def fit(self, X, y=None):
        self.encoder_dict = {}
        categories = ['State', 'Churn']
        for cat in categories:
            encoder = LabelEncoder()
            encoder.fit(X[cat])
            self.encoder_dict[cat] = encoder

        return self

    def transform(self, X):
        X_transformed = X.copy()
        for column, encoder in self.encoder_dict.items():
            new_categories = set(X[column].unique()) - set(encoder.classes_)
            if new_categories:
                all_categories = np.concatenate([encoder.classes_, list(new_categories)])
                encoder.fit(all_categories)
            X_transformed[column] = encoder.transform(X[column])

        return X_transformed

# %% [markdown]
# ### OneHot Encoder

# %%
# Wrapper class for the encoder that ransforms all the remaining categorical features using OneHot encoder

from sklearn.preprocessing import OneHotEncoder

class TransformOneHotMethod(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.encoder_dict = {}

    def fit(self, X, y=None):
        self.encoder_dict = {}
        for column in X.columns:
            if not pd.api.types.is_numeric_dtype(X[column]):
                encoder = OneHotEncoder(sparse_output=False)
                encoder.fit(X[column].values.reshape(-1, 1))
                self.encoder_dict[column] = encoder

        return self

    def transform(self, X):
        X_transformed = X.copy()
        for column, encoder in self.encoder_dict.items():
            new_categories = set(X[column].unique()) - set(encoder.categories_[0])
            if new_categories:
                updated_categories = np.concatenate([encoder.categories_[0], list(new_categories)])
                encoder.fit(updated_categories.reshape(-1, 1))

            transformation = encoder.transform(X[column].values.reshape(-1, 1))
            modified_cat = [f"{column}({cat})" for cat in encoder.categories_[0]]
            column_transformed = pd.DataFrame(transformation, columns=modified_cat)
            X_transformed = X_transformed.drop(column, axis=1).join(column_transformed)

        return X_transformed

# %% [markdown]
# **<font color=#3498db ><h2>
# 3- Feature Scaling</p><h2>**

# %% [markdown]
# ### Min-Max Method

# %%
# Wrppaer class for MinMax Feature Scaling

from sklearn.preprocessing import MinMaxScaler

class MinMaxScalerTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.encoder_dict = {}

    def fit(self, X, y=None):
        self.encoder_dict = {}
        for column in X:
            encoder = MinMaxScaler()
            encoder.fit(X[column].values.reshape(-1, 1))
            self.encoder_dict[column] = encoder

        return self

    def transform(self, X):
        X_transformed = X.copy()
        for column, encoder in self.encoder_dict.items():
            X_transformed[column] = encoder.transform(X_transformed[column].values.reshape(-1, 1))

        return X_transformed

# %% [markdown]
# **<font color=#3498db ><h2>
# 4- Feature Engineering</p><h2>**

# %%
Data.info()

# %%
# Wrapper class for feature engineering

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import LabelEncoder

class GeneratingFeatures(BaseEstimator, TransformerMixin):

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_transformed = X.copy()

        X_transformed['Total calls'] = X['Total day calls'] + X['Total eve calls'] + X['Total night calls']
        X_transformed['Total charge'] = X['Total day charge'] + X['Total eve charge'] + X['Total night charge']
        X_transformed['Perc of customer service calls'] = (X['Customer service calls'] / X_transformed['Total calls']) * 100
        X_transformed['Day to night usage ratio'] = X['Total day calls'] / X['Total night calls']
        X_transformed['Customer service call rate perc'] = X['Customer service calls'] / X['Account length']
        X_transformed['Profitability'] = X_transformed['Total charge'] / X['Account length']

        return X_transformed

# %% [markdown]
# **<font color=#3498db ><h2>
# 5- Balancing the Target feature (Churn)</p><h2>**

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.pipeline import Pipeline as pip

def balance_target(data):
    X = data.drop('Churn', axis=1)
    y = data['Churn']

    smote = SMOTE(random_state=42)
    enn = EditedNearestNeighbours()

    resample_pipeline = pip(steps=[('smote', smote), ('enn', enn)])
    X_train_balanced, y_train_balanced = resample_pipeline.fit_resample(X, y)

    new_data = X_train_balanced.copy()
    new_data['Churn'] = y_train_balanced

    return new_data

# %%
testtt = Data.copy()
testtt['Churn'].value_counts()

# %% [markdown]
# **<font color=#3498db ><h2>
# 6- Constructing Data Preparation Pipelines</p><h2>**

# %%
from sklearn.pipeline import Pipeline

transformation_pipeline = Pipeline([
    ('drop_transformer', DropColumnTransformer()),
    ('outliers_transformer', HandleOutliersTransformer()),
    ('label_transformer', TransformLabelMethod()),
    ('One-Hot_transformer', TransformOneHotMethod()),
    ('scaler', MinMaxScalerTransformer())
])

# %%
feature_engineering_pipeline = Pipeline([
    ('drop_transformer', DropColumnTransformer()),
    ('outliers_transformer', HandleOutliersTransformer()),
    ('label_transformer', TransformLabelMethod()),
    ('One-Hot_transformer', TransformOneHotMethod()),
    ('feature_engineering_transformer', GeneratingFeatures()),
])
scaling_pipeline = Pipeline([
    ('scaling', MinMaxScalerTransformer())
])

# %%
original_data_pipeline = Pipeline([
    ('drop_transformer', DropColumnTransformer()),
    ('outliers_transformer', HandleOutliersTransformer()),
    ('label_transformer', TransformLabelMethod()),
    ('One-Hot_transformer', TransformOneHotMethod()),
    ('feature_engineering_transformer', GeneratingFeatures()),
])

# %%
# Without feature engineering

train_set_transformed = transformation_pipeline.fit_transform(train_set)
test_set_transformed = transformation_pipeline.transform(test_set)

# %%
# With feature engineering

train_set_transformed_f = feature_engineering_pipeline.fit_transform(train_set)
test_set_transformed_f = feature_engineering_pipeline.transform(test_set)

# %%
train_set_transformed_f = balance_target(train_set_transformed_f)

# %%
train_set_transformed_f = scaling_pipeline.fit_transform(train_set_transformed_f)
test_set_transformed_f = scaling_pipeline.transform(test_set_transformed_f)

# %%
train_set_transformed_f
# Out:
#       State  Account length  Area code  Number vmail messages  \
# 0      0.32        0.524793   0.068627               0.531915
# 1      0.70        0.438017   0.068627               0.553191
# 2      0.62        0.561983   0.068627               0.000000
# 3      0.70        0.342975   0.000000               0.000000
# 4      0.72        0.305785   0.068627               0.000000
# ...     ...             ...        ...                    ...
# 4054   0.28        0.280992   1.000000               0.000000
# 4055   0.46        0.727273   0.000000               0.000000
# 4056   0.34        0.326446   1.000000               0.000000
# 4057   0.60        0.367769   0.039216               0.000000
# 4058   0.62        0.595041   1.000000               0.000000
#
#       Total day calls  Total day charge  Total eve calls  Total eve charge  \
# 0            0.600000          0.798760         0.481132          0.492518
# ...

# %% [markdown]
# **<font color=#3498db ><h2>
# 6- PCA</p><h2>**

# %% [markdown]
# ### Standardization:

# %%
# Wrppaer class for Standard Feature Scaling

from sklearn.preprocessing import StandardScaler

class StanderScalerTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.encoder_dict = {}

    def fit(self, X, y=None):
        self.encoder_dict = {}
        for column in X:
            encoder = StandardScaler()
            encoder.fit(X[[column]])
            self.encoder_dict[column] = encoder

        return self

    def transform(self, X):
        X_transformed = X.copy()
        for column, encoder in self.encoder_dict.items():
            X_transformed[column] = encoder.transform(X_transformed[[column]])

        return X_transformed

# %%
stadard_scaler_pipeline = Pipeline([
    ('scaler', StanderScalerTransformer())
])

# %%
pca_data = feature_engineering_pipeline.fit_transform(Data)
pca_data = stadard_scaler_pipeline.fit_transform(pca_data)

# %% [markdown]
# Determining the best number of components:

# %%
from sklearn.decomposition import PCA

# Fit PCA without specifying components
pca = PCA()
pca.fit(pca_data)  # `scaled_data` should be standardized

# Plot cumulative explained variance
cumulative_variance = pca.explained_variance_ratio_.cumsum()
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance vs. Number of Components')
plt.grid()
plt.show()

for i, var in enumerate(cumulative_variance):
    print(f"Component {i+1}: {var:.2f}")
# Out:
# Component 1: 0.12
# Component 2: 0.22
# Component 3: 0.31
# Component 4: 0.40
# Component 5: 0.48
# Component 6: 0.56
# Component 7: 0.63
# Component 8: 0.67
# Component 9: 0.71
# Component 10: 0.76
# Component 11: 0.80
# Component 12: 0.84
# Component 13: 0.88
# Component 14: 0.92
# Component 15: 0.95
# Component 16: 0.98
# Component 17: 1.00
# Component 18: 1.00
# Component 19: 1.00
# Component 20: 1.00
# Component 21: 1.00
# Component 22: 1.00
# Component 23: 1.00
# Component 24: 1.00

# %% [markdown]
# ### Interpretation:
# When analyzing the explained variance of our components, we notice that the variance starts to slow down after certain points. By selecting components 7, 10, and 14, we are focusing on the points where the cumulative variance levels off.

# %%
# PCA with 7 components retains 63% of the variance

pca_7 = PCA(n_components=7)
pca_7.fit(pca_data)
reduced_data_7 = pca.transform(pca_data)

# %%
# PCA with 10 components retains 76% of the variance

pca = PCA(n_components=10)
reduced_data_10 = pca.fit_transform(pca_data)

# %%
# PCA with 14 components retains 92% of the variance

pca = PCA(n_components=14)
reduced_data_14 = pca.fit_transform(pca_data)

# %%
pca_df_7 = pd.DataFrame(reduced_data_7, columns=[f'PC{i+1}' for i in range(reduced_data_7.shape[1])])
pca_df_7
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7
# 0    -2.672587 -0.997902 -0.530896  0.684374  2.012411 -0.056751 -0.590925
# 1    -2.639007 -0.797611  0.895823  0.761944  0.105859  1.020359 -0.132433
# 2     0.922904 -1.759037  1.382181  0.228778  0.495277  0.185779 -0.077073
# 3     1.152699 -1.839945 -1.806154 -0.747807 -3.715920  1.522877  0.815902
# 4     0.778789 -3.537429 -1.791214 -1.027710 -1.704642 -1.477825  1.098424
# ...        ...       ...       ...       ...       ...       ...       ...
# 3064 -2.540130  0.782677  0.902258 -0.158354 -0.864670  0.574026 -0.485058
# 3065 -2.664826 -0.293766  1.762221  3.242308 -0.950845  1.887142 -0.002618
# 3066  1.178637 -0.034463  0.919923 -1.328101 -0.946782  2.642062 -0.147244
# 3067  1.063765 -0.437878  0.953383  1.701760  0.205101 -0.106554 -0.463532
# 3068  0.967444 -2.240599 -1.956549 -1.424923 -3.291801 -0.523360 -0.240557
#
# [3069 rows x 7 columns]

# %%
pca_df_10 = pd.DataFrame(reduced_data_10, columns=[f'PC{i+1}' for i in range(reduced_data_10.shape[1])])
pca_df_10
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -2.672587 -0.997902 -0.530896  0.684374  2.012411 -0.056751 -0.590925
# 1    -2.639007 -0.797611  0.895823  0.761944  0.105859  1.020359 -0.132433
# 2     0.922904 -1.759037  1.382181  0.228778  0.495277  0.185779 -0.077073
# 3     1.152699 -1.839945 -1.806154 -0.747807 -3.715920  1.522877  0.815902
# 4     0.778789 -3.537429 -1.791214 -1.027710 -1.704642 -1.477825  1.098424
# ...        ...       ...       ...       ...       ...       ...       ...
# 3064 -2.540130  0.782677  0.902258 -0.158354 -0.864670  0.574026 -0.485058
# 3065 -2.664826 -0.293766  1.762221  3.242308 -0.950845  1.887142 -0.002618
# 3066  1.178637 -0.034463  0.919923 -1.328101 -0.946782  2.642062 -0.147244
# 3067  1.063765 -0.437878  0.953383  1.701760  0.205101 -0.106554 -0.463532
# 3068  0.967444 -2.240599 -1.956549 -1.424923 -3.291801 -0.523360 -0.240557
#
#            PC8       PC9      PC10
# ...

# %%
pca_df_14 = pd.DataFrame(reduced_data_14, columns=[f'PC{i+1}' for i in range(reduced_data_14.shape[1])])
pca_df_14
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -2.672587 -0.997902 -0.530896  0.684374  2.012411 -0.056751 -0.590925
# 1    -2.639007 -0.797611  0.895823  0.761944  0.105859  1.020359 -0.132433
# 2     0.922904 -1.759037  1.382181  0.228778  0.495277  0.185779 -0.077073
# 3     1.152699 -1.839945 -1.806154 -0.747807 -3.715920  1.522877  0.815902
# 4     0.778789 -3.537429 -1.791214 -1.027710 -1.704642 -1.477825  1.098424
# ...        ...       ...       ...       ...       ...       ...       ...
# 3064 -2.540130  0.782677  0.902258 -0.158354 -0.864670  0.574026 -0.485058
# 3065 -2.664826 -0.293766  1.762221  3.242308 -0.950845  1.887142 -0.002618
# 3066  1.178637 -0.034463  0.919923 -1.328101 -0.946782  2.642062 -0.147244
# 3067  1.063765 -0.437878  0.953383  1.701760  0.205101 -0.106554 -0.463532
# 3068  0.967444 -2.240599 -1.956549 -1.424923 -3.291801 -0.523360 -0.240557
#
# ...

# %% [markdown]
# **<font color=#f39c12 ><h1>
#  🧑‍💻 IV-Modeling</p><h1>**

# %% [markdown]
# **<font color=#3498db ><h2>
# DSO 1: Implementing machine learning techniques for customer retention and churn
#  prediction in telecommunications</p><h2>**

# %%
X_train = train_set_transformed_f.drop('Churn', axis=1)
X_test = test_set_transformed_f.drop('Churn', axis=1)
y_train = train_set_transformed_f['Churn']
y_test = test_set_transformed_f['Churn']

# %% [markdown]
# ## SVC:

# %%
from sklearn.model_selection import KFold, cross_validate

# %% [markdown]
# ### Linear SVC

# %% [markdown]
# Without Hyper-parameter tuning

# %%
from sklearn.svm import SVC

svm_linearW = SVC(kernel='linear')

svm_linearW.fit(X_train, y_train)
y_pred_linear_SVC_W = svm_linearW.predict(X_test)

# %% [markdown]
# With Hyper-parameter tuning

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

param_grid = {'C': np.logspace(np.log10(0.001641949), np.log10(464.0812108), num=200)}

svm_linear = SVC(kernel='linear')
grid_search = GridSearchCV(svm_linear, param_grid, scoring='f1', cv=5)
grid_search.fit (X_train, y_train)

print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)

# %%
svm_linear = SVC(kernel='linear', C=180.17599376421356)
svm_linear.fit(X_train, y_train)
y_pred_linear_SVC = svm_linear.predict(X_test)

# %% [markdown]
# ### Polynomial SVC

# %% [markdown]
# Without Hyper-parameter Tuning

# %%
svm_polyW = SVC(kernel='poly')

svm_polyW.fit(X_train, y_train)
y_pred_poly_SVC_W = svm_polyW.predict(X_test)

# %% [markdown]
# With Hyper-parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

poly_param_grid = {
    'kernel': ['poly'],
    'C': np.logspace(np.log10(0.001641949), np.log10(464.0812108), num=100),
    'degree': [2, 3, 4],
    'coef0': [0, 1, 10]
}
poly_SVC = SVC()

grid_search_poly_SVC = GridSearchCV(poly_SVC, poly_param_grid, scoring='f1', cv=3, n_jobs=-1, verbose=2)
grid_search_poly_SVC.fit (X_train, y_train)

# %%
print("Best Parameters:", grid_search_poly_SVC.best_params_)
print("Best Score:", grid_search_poly_SVC.best_score_)
# Out:
# Best Parameters: {'C': 4.258571922670366, 'coef0': 0, 'degree': 4, 'kernel': 'poly'}
# Best Score: 0.9292615996077305

# %%
svm_poly = SVC(kernel='poly', C=4.258571922670366, coef0=0, degree=4)

svm_poly.fit(X_train, y_train)
y_pred_poly_SVC = svm_poly.predict(X_test)

# %% [markdown]
# ### RBF

# %% [markdown]
# Without Hyper-parameter Tuning

# %%
RBF_SVC = SVC(kernel="rbf")
RBF_SVC.fit(X_train, y_train)
y_pred_RBF_SVC_W = RBF_SVC.predict(X_test)

# %% [markdown]
# With Hyper-parameter Tuning

# %%
RBF_SVC = SVC(kernel="rbf")

poly_param_grid = {
    'kernel': ['rbf'],
    'C': np.logspace(np.log10(0.001641949), np.log10(464.0812108), num=100),
    'gamma': [1, 0.1, 0.01, 0.001]
}

grid_search_RBF_SVC = GridSearchCV(poly_SVC, poly_param_grid, scoring='f1', cv=3, n_jobs=-1, verbose=2)
grid_search_RBF_SVC.fit (X_train, y_train)

# %%
print("Best Parameters:", grid_search_RBF_SVC.best_params_)
print("Best Score:", grid_search_RBF_SVC.best_score_)
# Out:
# Best Parameters: {'C': 25.127287432344225, 'gamma': 1, 'kernel': 'rbf'}
# Best Score: 0.9438797242230517

# %%
RBF_SVC = SVC(kernel="rbf", C=25.12728743234422, gamma=1)
RBF_SVC.fit(X_train, y_train)
y_pred_RBF_SVC = RBF_SVC.predict(X_test)

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# Without Hyper-parameter tuning

# %%
from sklearn.linear_model import LogisticRegression

logReg_W = LogisticRegression()
logReg_W.fit(X_train, y_train)
y_pred_logReg_W = logReg_W.predict(X_test)

# %% [markdown]
# With Hyper-parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

logReg = LogisticRegression(max_iter=1000)
param_grid = {'C': np.logspace(np.log10(5.15e-5), np.log10(453.4347358), num=5000)}
grid_search = GridSearchCV(logReg, param_grid, scoring='f1', cv=3, n_jobs=-1, verbose=2)
grid_search.fit (X_train, y_train)

# %%
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)

# %%
logReg = LogisticRegression(C=450.5431051610441, max_iter=1000)
logReg.fit(X_train, y_train)
y_pred_logReg = logReg.predict(X_test)

# %% [markdown]
# ### Neural Networks:

# %% [markdown]
# Without Hyper-parameter Tuning

# %%
# Importation des bibliothèques nécessaires
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import classification_report

# Création du modèle sans ajustement de paramètres
nn_model_default = Sequential([
    Dense(64, input_dim=X_train.shape[1], activation='relu'),  # Couche cachée par défaut
    Dense(1, activation='sigmoid')  # Couche de sortie pour la classification binaire
])

# Compilation du modèle (paramètres par défaut)
nn_model_default.compile(
    optimizer='adam',  # Optimiseur par défaut
    loss='binary_crossentropy',  # Perte pour la classification binaire
    metrics=['accuracy']
)

# Entraînement du modèle
nn_model_default.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Prédiction sur l'ensemble de test
y_pred_NN = (nn_model_default.predict(X_test) > 0.5).astype("int32")
# Out:
# Epoch 1/10
# C:\Users\ibrah\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6016 - loss: 0.6764 - val_accuracy: 0.6969 - val_loss: 0.6146
# Epoch 2/10
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7655 - loss: 0.5544 - val_accuracy: 0.7562 - val_loss: 0.5687
# Epoch 3/10
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7815 - loss: 0.5162 - val_accuracy: 0.7578 - val_loss: 0.5492
# Epoch 4/10
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7850 - loss: 0.5007 - val_accuracy: 0.7578 - val_loss: 0.5427
# Epoch 5/10
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7798 - loss: 0.4916 - val_accuracy: 0.7825 - val_loss: 0.4967
# ...

# %% [markdown]
# With Hyper-parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# Définir une grille d'hyperparamètres pour MLPClassifier
param_grid = {
    'hidden_layer_sizes': list(range(5, 9)),
    'activation': ['relu'],
    'solver': ['adam'],
}

# Initialiser le modèle
mlp = MLPClassifier(max_iter=1000, random_state=42)

# Configurer GridSearchCV
grid_search = GridSearchCV(
    mlp,
    param_grid,
    scoring='f1',
    cv=3,
    verbose=2,
    n_jobs=-1
)

# Effectuer la recherche sur les données d'entraînement
grid_search.fit(X_train, y_train)

# Meilleurs paramètres trouvés
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)

# %%
best_mlp = grid_search.best_estimator_
best_mlp.fit(X_train, y_train)
y_pred_NN = best_mlp.predict(X_test)

# %% [markdown]
# ### XGBoost

# %% [markdown]
# Without Hyper-paramete Tuning

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier()
xgb.fit(X_train, y_train)
y_pred_xgb_W = xgb.predict(X_test)

# %% [markdown]
# With Hyper-parameter Tuning

# %%
xgb = XGBClassifier()

param_grid = {
    'n_estimators': list(range(100, 1000, 5)),
    'learning_rate': list(np.arange(0.01, 0.3, 0.02)),
    'max_depth': list(range(3, 10)),
}

grid_search = GridSearchCV(xgb, param_grid, scoring='f1', cv=2, n_jobs=-1, verbose=2)
grid_search.fit (X_train, y_train)

print("Best Parameters:", grid_search.best_params_)

print("Best Score:", grid_search.best_score_)

# %%
xgb = XGBClassifier(n_estimators=440, learning_rate=0.16999999999999998, max_depth=5)
xgb.fit(X_train, y_train)
y_pred_xgb = xgb.predict(X_test)

# %%
import pickle

# Save the model to a .pkl file
with open('model.pkl', 'wb') as file:
    pickle.dump(xgb, file)

# %% [markdown]
# ### AdaBoost

# %% [markdown]
# Without Hyper-parameter tuning

# %%
from sklearn.ensemble import AdaBoostClassifier

ada = AdaBoostClassifier()
ada.fit(X_train, y_train)
y_pred_ada_W = ada.predict(X_test)
# Out:
# C:\Users\ibrah\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %% [markdown]
# With Hyper-parameter tuning

# %%
ada = AdaBoostClassifier()

param_grid = {
    'n_estimators': list(range(50, 501, 2)),
    'learning_rate': list(np.arange(0.01, 0.3, 0.02)),
}

grid_search = GridSearchCV(ada, param_grid, scoring='f1', cv=3, n_jobs=-1, verbose=2)
grid_search.fit (X_train, y_train)

print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)

# %%
ada = AdaBoostClassifier(learning_rate=0.26999, n_estimators=462)
ada.fit(X_train, y_train)
y_pred_ada = ada.predict(X_test)
# Out:
# C:\Users\ibrah\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %% [markdown]
# ### Random Forest

# %% [markdown]
# Without Hyper-parameter tuning

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
y_pred_rf_W = rf_model.predict(X_test)

# %% [markdown]
# With Hyper-parametr tuning

# %%
param_grid = {
    'n_estimators': range(14, 21),
    'max_depth': range(9, 21)
}

grid_search = GridSearchCV(rf_model, param_grid, scoring='f1', cv=3, n_jobs=-1, verbose=2)
grid_search.fit (X_train, y_train)

print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)

# %%
rf_model = RandomForestClassifier(max_depth=20, n_estimators=20)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

# %% [markdown]
# ### GBM

# %% [markdown]
# Without Hyper-parameter tuning

# %%
from sklearn.ensemble import GradientBoostingClassifier

GBM_W = GradientBoostingClassifier()
GBM_W.fit(X_train, y_train)
y_pred_GBM_W = GBM_W.predict(X_test)

# %% [markdown]
# With Hyper-parameters Tuning

# %%
GBM = GradientBoostingClassifier()

GBM_param_grid = {
    'max_depth': list(range(5, 29)),
    'min_samples_leaf': list(range(5, 10)),
    'max_features': ['sqrt', 'log2', None],
    'max_leaf_nodes': list(range(3, 7))
}

grid_search = GridSearchCV(GBM, GBM_param_grid, cv=3, scoring='f1', n_jobs=-1, verbose=2)
grid_search.fit (X_train, y_train)

print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)

# %%
GBM = GradientBoostingClassifier(max_depth=5, max_features=None, max_leaf_nodes=6, min_samples_leaf=6)
GBM.fit (X_train, y_train)
y_pred_GBM = GBM_W.predict(X_test)

# %% [markdown]
# **<font color=#3498db ><h1>
#   DSO 3 :Customer churn prediction in telecom sector using machine
# learning techniques</p><h1>**

# %% [markdown]
# ### Using 7 components:

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

linked_7 = linkage(reduced_data_7, method='ward')
plt.figure(figsize=(10, 7))
dendrogram(linked_7)
plt.title('Dendrogram')
plt.xlabel('Sample index')
plt.ylabel('Distance')
plt.show()

# %%
from scipy.cluster.hierarchy import fcluster

pca_df_7_2 = pca_df_7.copy()
pca_df_7_3 = pca_df_7.copy()
pca_df_7_4 = pca_df_7.copy()

clusters = fcluster(linked_7, t=3, criterion='maxclust')
pca_df_7_2['cluster'] = fcluster(linked_7, t=2, criterion='maxclust')
pca_df_7_3['cluster'] = fcluster(linked_7, t=3, criterion='maxclust')
pca_df_7_4['cluster'] = fcluster(linked_7, t=4, criterion='maxclust')

# %% [markdown]
# ### Using 10 components:

# %%
linked_10 = linkage(reduced_data_10, method='ward')
plt.figure(figsize=(10, 7))
dendrogram(linked_10)
plt.title('Dendrogram')
plt.xlabel('Sample index')
plt.ylabel('Distance')
plt.show()

# %%
pca_df_10_2 = pca_df_10.copy()
pca_df_10_3 = pca_df_10.copy()
pca_df_10_4 = pca_df_10.copy()

clusters = fcluster(linked_7, t=3, criterion='maxclust')
pca_df_10_2['cluster'] = fcluster(linked_10, t=2, criterion='maxclust')
pca_df_10_3['cluster'] = fcluster(linked_10, t=3, criterion='maxclust')
pca_df_10_4['cluster'] = fcluster(linked_10, t=4, criterion='maxclust')

# %% [markdown]
# ### Using 14 components:

# %%
linked_14 = linkage(reduced_data_14, method='ward')
plt.figure(figsize=(10, 7))
dendrogram(linked_14)
plt.title('Dendrogram')
plt.xlabel('Sample index')
plt.ylabel('Distance')
plt.show()

# %%
pca_df_14_2 = pca_df_14.copy()
pca_df_14_3 = pca_df_14.copy()
pca_df_14_4 = pca_df_14.copy()

clusters = fcluster(linked_14, t=3, criterion='maxclust')
pca_df_10_2['cluster'] = fcluster(linked_7, t=2, criterion='maxclust')
pca_df_10_3['cluster'] = fcluster(linked_7, t=3, criterion='maxclust')
pca_df_10_4['cluster'] = fcluster(linked_7, t=4, criterion='maxclust')

# %% [markdown]
# **<font color=#f39c12 ><h1>
#  V-Evaluation </p><h1>**

# %% [markdown]
# **<font color=#3498db ><h2>
#  DSO 1: Churn Prediction</p><h2>**

# %%
from sklearn.metrics import roc_curve, auc

fprLinear, tprLinear, thresholdLinear = roc_curve(y_test, y_pred_linear_SVC)
roc_aucLinear = auc(fprLinear, tprLinear)

fprPoly, tprPoly, thresholdPoly = roc_curve(y_test, y_pred_poly_SVC)
roc_aucPoly = auc(fprPoly, tprPoly)

fprRBF, tprRBF, thresholdRBF = roc_curve(y_test, y_pred_RBF_SVC)
roc_aucRBF = auc(fprRBF, tprRBF)

# %%
plt.figure()

plt.plot(fprLinear, tprLinear, color='green', lw=2, label='Linear SVC ROC curve (area = %0.2f)'% roc_aucLinear)

plt.plot(fprPoly, tprPoly, color='blue', lw=2, label='Polynomial SVC ROC curve (area = %0.2f)'% roc_aucPoly)

plt.plot(fprRBF, tprRBF, color='red', lw=2, label='RBF SVC ROC curve (area = %0.2f)'% roc_aucRBF)

plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Classifiers ROC curves')
plt.legend(loc = "lower right")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

fpr1, tpr1, threshold1 = roc_curve(y_test, y_pred_poly_SVC)
roc_auc1 = auc(fpr1, tpr1)
fpr2, tpr2, threshold2 = roc_curve(y_test, y_pred_logReg)
roc_auc2 = auc(fpr2, tpr2)
fpr3, tpr3, threshold3 = roc_curve(y_test, y_pred_NN)
roc_auc3 = auc(fpr3, tpr3)
fpr4, tpr4, threshold4 = roc_curve(y_test, y_pred_xgb)
roc_auc4 = auc(fpr4, tpr4)
fpr5, tpr5, threshold5 = roc_curve(y_test, y_pred_ada)
roc_auc5 = auc(fpr5, tpr5)
fpr6, tpr6, threshold6 = roc_curve(y_test, y_pred_rf)
roc_auc6 = auc(fpr6, tpr6)
fpr7, tpr7, threshold7 = roc_curve(y_test, y_pred_GBM)
roc_auc7 = auc(fpr7, tpr7)

plt.figure(figsize=(7,7))
plt.plot(fpr1, tpr1, color='yellow', lw=2, label='Support Vector Machines Polynomial (area = %0.2f)'% roc_auc1)
plt.plot(fpr2, tpr2, color='red', lw=2, label='Logistic Regression (area = %0.2f)'% roc_auc2)
plt.plot(fpr3, tpr3, color='cyan', lw=2, label='Neural Networks (area = %0.2f)'% roc_auc3)
plt.plot(fpr4, tpr4, color='magenta', lw=2, label='XGBoost (area = %0.2f)'% roc_auc4)
plt.plot(fpr5, tpr5, color='blue', lw=2, label='AdaBoost (area = %0.2f)'% roc_auc5)
plt.plot(fpr6, tpr6, color='black', lw=2, label='Random Forest (area = %0.2f)'% roc_auc6)
plt.plot(fpr6, tpr6, color='green', lw=2, label='GBM (area = %0.2f)'% roc_auc7)
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Classifiers ROC curves')
plt.legend(loc = "lower right")
plt.show()

# %% [markdown]
# ### K-Fold Cross validation:

# %%
from sklearn.model_selection import KFold, cross_validate

# %%
def k_foldResults(metrics, scores):
    accScores = scores[f'test_accuracy']
    precScore = scores[f'test_precision_macro']
    reclScore = scores[f'test_recall_macro']
    f1Score = scores[f'test_f1_macro']
    rocScores = scores[f'test_roc_auc']

    accMean = accScores.mean()
    precMean = precScore.mean()
    reclMean = reclScore.mean()
    f1Mean = f1Score.mean()
    rocMean = rocScores.mean()

    accStd = accScores.std()
    precStd= precScore.std()
    reclStd = reclScore.std()
    f1Std = f1Score.std()
    rocStd = rocScores.std()

    scores = [accScores, precScore, reclScore, f1Score, rocScores]
    means = [accMean, precMean, reclMean, f1Mean, rocMean]
    stds = [accStd, precStd, reclStd, f1Std, rocStd]

    return scores, means, stds

# %%
# Scores for the linear SVC

svm_linear = SVC(kernel='linear', C=0.198261367812289298)

kf = KFold(n_splits=6, shuffle=True, random_state=42)
metrics = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro', 'roc_auc']
scores = cross_validate(svm_linear, X_train, y_train, cv=kf, scoring=metrics, return_train_score=True)

for metric in metrics:
    print(f"{metric.capitalize()}:")
    print(f"  Test scores: {scores[f'test_{metric}']}")
    print(f"  Mean: {scores[f'test_{metric}'].mean():.3f}, Std: {scores[f'test_{metric}'].std():.3f}\n")

svm_l_socres, svm_l_means, svm_l_stds = k_foldResults(metrics, scores)
# Out:
# Accuracy:
#   Test scores: [0.79615953 0.81979321 0.78434269 0.79585799 0.79142012 0.77071006]
#   Mean: 0.793, Std: 0.015
#
# Precision_macro:
#   Test scores: [0.79496856 0.81919071 0.78516077 0.79688382 0.79150971 0.77082622]
#   Mean: 0.793, Std: 0.014
#
# Recall_macro:
#   Test scores: [0.79566759 0.81895026 0.78395105 0.79480306 0.79084315 0.77071006]
#   Mean: 0.792, Std: 0.015
#
# F1_macro:
#   Test scores: [0.79525492 0.81906327 0.78399913 0.79514072 0.79103555 0.77068547]
#   Mean: 0.793, Std: 0.015
#
# Roc_auc:
#   Test scores: [0.85421128 0.87436275 0.85791973 0.86162216 0.85299271 0.83042435]
#   Mean: 0.855, Std: 0.013

# %%
# Scores for the logistic Regression

kf = KFold(n_splits=6, shuffle=True, random_state=42)
metrics = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro', 'roc_auc']
scores = cross_validate(logReg, X_train, y_train, cv=kf, scoring=metrics, return_train_score=True)

logReg_socres, logReg_means, logReg_stds = k_foldResults(metrics, scores)

# %%
# Scores for the Neural Network model
from tensorflow.keras.optimizers import Adam
from scikeras.wrappers import KerasClassifier

def create_nn_model():
    model = Sequential([
        Dense(7, activation='relu', input_dim=X_train.shape[1]),
        Dense(1, activation='sigmoid')
    ])
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

NNmodel = KerasClassifier(model=create_nn_model, epochs=50, batch_size=32, verbose=0)

kf = KFold(n_splits=6, shuffle=True, random_state=42)
metrics = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro', 'roc_auc']
scores = cross_validate(NNmodel, X_train, y_train, cv=kf, scoring=metrics, return_train_score=True)

NN_socres, NN_means, NN_stds = k_foldResults(metrics, scores)
# Out:
# C:\Users\ibrah\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\ibrah\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\ibrah\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# ...

# %%
# Scores for the XGBoost

kf = KFold(n_splits=6, shuffle=True, random_state=42)
metrics = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro', 'roc_auc']
scores = cross_validate(xgb, X_train, y_train, cv=kf, scoring=metrics, return_train_score=True)

XGB_socres, XGB_means, XGB_stds = k_foldResults(metrics, scores)

# %%
# Scores for the AdaBoost

kf = KFold(n_splits=6, shuffle=True, random_state=42)
metrics = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro', 'roc_auc']
scores = cross_validate(ada, X_train, y_train, cv=kf, scoring=metrics, return_train_score=True)

ada_socres, ada_means, ada_stds = k_foldResults(metrics, scores)
# Out:
# C:\Users\ibrah\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\ibrah\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\ibrah\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\ibrah\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
# ...

# %%
# Scores for the Random Forest

kf = KFold(n_splits=6, shuffle=True, random_state=42)
metrics = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro', 'roc_auc']
scores = cross_validate(rf_model, X_train, y_train, cv=kf, scoring=metrics, return_train_score=True)

rf_socres, rf_means, rf_stds = k_foldResults(metrics, scores)

# %%
# Scores for the GBM

kf = KFold(n_splits=6, shuffle=True, random_state=42)
metrics = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro', 'roc_auc']
scores = cross_validate(GBM, X_train, y_train, cv=kf, scoring=metrics, return_train_score=True)

GBM_socres, GBM_means, GBM_stds = k_foldResults(metrics, scores)

# %%
K_fold_comparison = pd.DataFrame({
    'Model': ['Support Vector Machines Polynomial', 'Logistic Regression', 'Neural Networks', 'XGBoost', 'AdaBoost', 'Random Forest', 'GBM'],
    'Accuracy': [f"{svm_l_means[0]:.2f} {chr(0xB1)} {svm_l_stds[0]:.2f}",
                 f"{logReg_means[0]:.2f} {chr(0xB1)} {logReg_stds[0]:.2f}",
                 f"{NN_means[0]:.2f} {chr(0xB1)} {NN_stds[0]:.2f}",
                 f"{XGB_means[0]:.2f} {chr(0xB1)} {XGB_stds[0]:.2f}",
                 f"{ada_means[0]:.2f} {chr(0xB1)} {ada_stds[0]:.2f}",
                 f"{rf_means[0]:.2f} {chr(0xB1)} {rf_stds[0]:.2f}",
                 f"{GBM_means[0]:.2f} {chr(0xB1)} {GBM_stds[0]:.2f}"],
    'Precision': [f"{svm_l_means[1]:.2f} {chr(0xB1)} {svm_l_stds[1]:.2f}",
                  f"{logReg_means[1]:.2f} {chr(0xB1)} {logReg_stds[1]:.2f}",
                  f"{NN_means[1]:.2f} {chr(0xB1)} {NN_stds[1]:.2f}",
                  f"{XGB_means[1]:.2f} {chr(0xB1)} {XGB_stds[1]:.2f}",
                  f"{ada_means[1]:.2f} {chr(0xB1)} {ada_stds[1]:.2f}",
                  f"{rf_means[1]:.2f} {chr(0xB1)} {rf_stds[1]:.2f}",
                  f"{GBM_means[1]:.2f} {chr(0xB1)} {GBM_stds[1]:.2f}"],
    'Recall': [f"{svm_l_means[2]:.2f} {chr(0xB1)} {svm_l_stds[2]:.2f}",
               f"{logReg_means[2]:.2f} {chr(0xB1)} {logReg_stds[2]:.2f}",
               f"{NN_means[2]:.2f} {chr(0xB1)} {NN_stds[2]:.2f}",
               f"{XGB_means[2]:.2f} {chr(0xB1)} {XGB_stds[2]:.2f}",
               f"{ada_means[2]:.2f} {chr(0xB1)} {ada_stds[2]:.2f}",
               f"{rf_means[2]:.2f} {chr(0xB1)} {rf_stds[2]:.2f}",
               f"{GBM_means[2]:.2f} {chr(0xB1)} {GBM_stds[2]:.2f}"],
    'f1_score': [f"{svm_l_means[3]:.2f} {chr(0xB1)} {svm_l_stds[3]:.2f}",
                 f"{logReg_means[3]:.2f} {chr(0xB1)} {logReg_stds[3]:.2f}",
                 f"{NN_means[3]:.2f} {chr(0xB1)} {NN_stds[3]:.2f}",
                 f"{XGB_means[3]:.2f} {chr(0xB1)} {XGB_stds[3]:.2f}",
                 f"{ada_means[3]:.2f} {chr(0xB1)} {ada_stds[3]:.2f}",
                 f"{rf_means[3]:.2f} {chr(0xB1)} {rf_stds[3]:.2f}",
                 f"{GBM_means[3]:.2f} {chr(0xB1)} {GBM_stds[3]:.2f}"],
    'ROC-score': [f"{svm_l_means[4]:.2f} {chr(0xB1)} {svm_l_stds[4]:.2f}",
                  f"{logReg_means[4]:.2f} {chr(0xB1)} {logReg_stds[4]:.2f}",
                  f"{NN_means[4]:.2f} {chr(0xB1)} {NN_stds[4]:.2f}",
                  f"{XGB_means[4]:.2f} {chr(0xB1)} {XGB_stds[4]:.2f}",
                  f"{ada_means[4]:.2f} {chr(0xB1)} {ada_stds[4]:.2f}",
                  f"{rf_means[4]:.2f} {chr(0xB1)} {rf_stds[4]:.2f}",
                  f"{GBM_means[4]:.2f} {chr(0xB1)} {GBM_stds[4]:.2f}"]
})

# %%
K_fold_comparison
# Out:
#                                 Model     Accuracy    Precision       Recall  \
# 0  Support Vector Machines Polynomial  0.79 ± 0.01  0.79 ± 0.01  0.79 ± 0.01
# 1                 Logistic Regression  0.87 ± 0.01  0.87 ± 0.01  0.87 ± 0.01
# 2                     Neural Networks  0.82 ± 0.02  0.82 ± 0.02  0.82 ± 0.02
# 3                             XGBoost  0.97 ± 0.01  0.97 ± 0.01  0.97 ± 0.01
# 4                            AdaBoost  0.91 ± 0.01  0.91 ± 0.01  0.90 ± 0.01
# 5                       Random Forest  0.95 ± 0.01  0.95 ± 0.01  0.95 ± 0.01
# 6                                 GBM  0.95 ± 0.01  0.95 ± 0.01  0.94 ± 0.01
#
#       f1_score    ROC-score
# 0  0.79 ± 0.01  0.86 ± 0.01
# 1  0.87 ± 0.01  0.93 ± 0.00
# 2  0.82 ± 0.02  0.89 ± 0.02
# 3  0.97 ± 0.01  0.99 ± 0.00
# 4  0.91 ± 0.01  0.96 ± 0.01
# 5  0.95 ± 0.01  0.99 ± 0.00
# 6  0.95 ± 0.01  0.98 ± 0.00

# %% [markdown]
# ### Wilcoxon signed rank test:

# %%
from scipy.stats import wilcoxon

# %%
scores = {
    "SVC": np.array(svm_l_socres[2]),
    "Logistic Regression": np.array(logReg_socres[2]),
    "Neural Networks": np.array(NN_socres[2]),
    "XGBoost": np.array(XGB_socres[2]),
    "AdaBoost": np.array(ada_socres[2]),
    "Random forest": np.array(rf_socres[2]),
    "GBM": np.array(GBM_socres[2])
}

model_names = list(scores.keys())

model_1 = "XGBoost"

stat1, p_value1 = wilcoxon(scores[model_1], scores["SVC"])
stat2, p_value2 = wilcoxon(scores[model_1], scores["Logistic Regression"])
stat3, p_value3 = wilcoxon(scores[model_1], scores["Neural Networks"])
stat4, p_value4 = wilcoxon(scores[model_1], scores["GBM"])
stat5, p_value5 = wilcoxon(scores[model_1], scores["AdaBoost"])
stat6, p_value6 = wilcoxon(scores[model_1], scores["Random forest"])

Wilcoxon_test = pd.DataFrame({
    'Model': ['Linear SVC', 'Logistic Regression','Neural Networks', 'GBM', 'AdaBoost', 'Random forest'],
    'Statistic': [stat1, stat2, stat3, stat4, stat5, stat6],
    'p-value': [p_value1, p_value2, p_value3, p_value4, p_value5, p_value6]
})

Wilcoxon_test
# Out:
#                  Model  Statistic  p-value
# 0           Linear SVC        0.0  0.03125
# 1  Logistic Regression        0.0  0.03125
# 2      Neural Networks        0.0  0.03125
# 3                  GBM        0.0  0.03125
# 4             AdaBoost        0.0  0.03125
# 5        Random forest        0.0  0.03125

# %% [markdown]
# **<font color=#3498db ><h2>
#  DSO 2: Explaining customer churn prediction in telecom industry</p><h2>**

# %%
train_set
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# the whole data
original_data = feature_engineering_pipeline.fit_transform(train_set)
original_data = balance_target(original_data)
original_data_X = original_data.drop("Churn", axis=1)
original_data_y = original_data["Churn"]

# %%
import shap

explainer = shap.TreeExplainer(xgb)
shap_values = explainer.shap_values(X_train)

shap.summary_plot(shap_values, X_train, feature_names=X_train.columns)

plt.show()

# Save the plot to the static folder
plt.savefig(os.path.join('static', 'shap_plot.png'), bbox_inches='tight')  # Use bbox_inches='tight' to avoid clipping
plt.close()  # Close the plot to free memory

# %% [markdown]
# ***Interpretation***
#
# We notice that the "Perc of customer service calls", "Total charge", "International plan(Yes)" and "Voice mail plan(No)" are the most impactfull features on the model predictions

# %%
explainer = shap.TreeExplainer(xgb)
shap_values = explainer(X_train)

plt.figure(figsize=(10, 8))

plt.figure(figsize=(10, 8))
shap.dependence_plot(
    "Total charge",
    shap_values.values,
    original_data_X,
    interaction_index="Perc of customer service calls",
    show=True
)
plt.title(f"Feature Interaction of \"Total charge\" VS \"Perc of customer service calls\"")
plt.show()

# %%
explainer = shap.TreeExplainer(xgb)
shap_values = explainer(X_train)

plt.figure(figsize=(10, 8))

plt.figure(figsize=(10, 8))
shap.dependence_plot(
    "Total charge",
    shap_values.values,
    original_data_X,
    interaction_index="International plan(Yes)",
    show=True
)
plt.title(f"Feature Interaction of \"Total charge\" VS \"International plan(Yes)\"")
plt.show()

# %%
explainer = shap.TreeExplainer(xgb)
shap_values = explainer(X_train)

plt.figure(figsize=(10, 8))

plt.figure(figsize=(10, 8))
shap.dependence_plot(
    "Total charge",
    shap_values.values,
    original_data_X,
    interaction_index="Voice mail plan(No)",
    show=True
)
plt.title(f"Feature Interaction of {principal} VS {interaction}")
plt.show()

# %%
explainer = shap.TreeExplainer(xgb)
shap_values = explainer(X_train)

plt.figure(figsize=(10, 8))

plt.figure(figsize=(10, 8))
shap.dependence_plot(
    "Perc of customer service calls",
    shap_values.values,
    original_data_X,
    interaction_index="Voice mail plan(No)",
    show=True
)
plt.title(f"Feature Interaction of {principal} VS {interaction}")
plt.show()

# %%
explainer = shap.TreeExplainer(xgb)
shap_values = explainer(X_train)

plt.figure(figsize=(10, 8))

plt.figure(figsize=(10, 8))
shap.dependence_plot(
    "Account length",
    shap_values.values,
    original_data_X,
    interaction_index="Perc of customer service calls",
    show=True
)
plt.title(f"Feature Interaction of {principal} VS {interaction}")
plt.show()

# %% [markdown]
# ### Determining the most important features to the model:

# %%
features_importance = {}
features = X_train.columns
importances = xgb.feature_importances_

for feature, importance in zip(features, importances):
    features_importance[feature] = importance

features_importance = dict(sorted(features_importance.items(), key=lambda item: item[1], reverse=True))
features_importance
# Out:
# {'International plan(Yes)': 0.29493824,
#  'Total charge': 0.12521648,
#  'International plan(No)': 0.11188987,
#  'Voice mail plan(No)': 0.1055764,
#  'Perc of customer service calls': 0.06284036,
#  'Total intl calls': 0.049187575,
#  'Customer service calls': 0.040643882,
#  'Area code': 0.03575096,
#  'Total calls': 0.020359602,
#  'Total intl charge': 0.017844616,
#  'Account length': 0.01418613,
#  'Total eve charge': 0.012839123,
#  'Profitability': 0.012340027,
#  'Total day charge': 0.012182482,
#  'Customer service call rate perc': 0.0115692215,
#  'State': 0.011212139,
#  'Total night calls': 0.011038836,
#  'Number vmail messages': 0.01072434,
#  'Total day calls': 0.010191813,
#  'Day to night usage ratio': 0.0101598045,
#  'Total night charge': 0.009736625,
#  'Total eve calls': 0.009571487,
#  'Voice mail plan(Yes)': 0.0}

# %%
values = list(features_importance.values())

norm = plt.Normalize(min(values), max(values))

cmap = plt.get_cmap("coolwarm")

plt.figure(figsize=(12, 8))
bars = plt.barh(list(features_importance.keys()), values, color=cmap(norm(values)))

plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.title('Feature Importances with Gradient Colors')
plt.gca().invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Experimantal analysis:

# %%
plt.figure(figsize=(8, 5))
sns.kdeplot(data=original_data[original_data['Churn'] == 0], x="Total charge", label="Total Charge", fill=True, color='blue', alpha=0.5)
sns.kdeplot(data=original_data[original_data['Churn'] == 1], x="Total charge", label="Churn", fill=True, color='green', alpha=0.5)

plt.title("Total Charge by churn")
plt.xlabel("Total Charge")
plt.ylabel("Density")
plt.legend()

plt.show()

# %% [markdown]
# **<font color=#3498db ><h2>
#  DSO 3: Customers Clustering</p><h2>**

# %%
from sklearn.metrics import silhouette_score, silhouette_samples

sil_score_7_2 = silhouette_score(pca_df_7_2.drop('cluster', axis=1), pca_df_7_2['cluster'])
sil_score_7_3 = silhouette_score(pca_df_7_3.drop('cluster', axis=1), pca_df_7_3['cluster'])
sil_score_7_4 = silhouette_score(pca_df_7_4.drop('cluster', axis=1), pca_df_7_4['cluster'])

sil_score_7 = [sil_score_7_2, sil_score_7_3, sil_score_7_4]

# %%
sil_score_10_2 = silhouette_score(pca_df_10_2.drop('cluster', axis=1), pca_df_7_2['cluster'])
sil_score_10_3 = silhouette_score(pca_df_10_3.drop('cluster', axis=1), pca_df_7_3['cluster'])
sil_score_10_4 = silhouette_score(pca_df_10_4.drop('cluster', axis=1), pca_df_7_4['cluster'])

sil_score_10 = [sil_score_10_2, sil_score_10_3, sil_score_10_4]

# %%
sil_score_14_2 = silhouette_score(pca_df_14_2.drop('cluster', axis=1), pca_df_7_2['cluster'])
sil_score_14_3 = silhouette_score(pca_df_14_3.drop('cluster', axis=1), pca_df_7_3['cluster'])
sil_score_14_4 = silhouette_score(pca_df_14_4.drop('cluster', axis=1), pca_df_7_4['cluster'])

sil_score_14 = [sil_score_14_2, sil_score_14_3, sil_score_14_4]

# %%
all_scores = [sil_score_7, sil_score_10, sil_score_14]
categories = ['2 Clusters', '3 Clusters', '4 Clusters']  # x-axis labels
labels = ['Sil_Score_7', 'Sil_Score_10', 'Sil_Score_14']  # Legend labels

# Set up the bar plot
x = np.arange(len(categories))  # The x positions for the groups
bar_width = 0.25  # Width of the bars

# Create the plot
plt.figure(figsize=(10, 6))
for i, scores in enumerate(all_scores):
    plt.bar(x + i * bar_width, scores, bar_width, label=labels[i])

# Add labels, title, and legend
plt.title('Silhouette Scores Comparison', fontsize=16)
plt.xlabel('Cluster Configuration', fontsize=12)
plt.ylabel('Silhouette Score', fontsize=12)
plt.xticks(x + bar_width, categories)  # Position the x-axis labels
plt.legend(title='Categories')

# Add numerical values on top of the bars
for i, scores in enumerate(all_scores):
    for j, score in enumerate(scores):
        plt.text(x[j] + i * bar_width, score + 0.01, f"{score:.2f}", ha='center', fontsize=10)

# Show the plot
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ylim(0, 1)  # Adjust the y-axis limits if needed
plt.show()

# %% [markdown]
# ***Interpretation***
#
# We can see that applying CAH with 7 components have the highest score and there is no much difference between 3 clusters and 4 clusters, we will use 3 clusters with 7 components

# %%
pca_df_7_clust = pca_df_7.copy()
pca_df_7_clust['cluster'] = fcluster(linked_7, t=3, criterion='maxclust')

# %%
pca_df_7
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -2.672587 -0.997902 -0.530896  0.684374  2.012411 -0.056751 -0.590925
# 1    -2.639007 -0.797611  0.895823  0.761944  0.105859  1.020359 -0.132433
# 2     0.922904 -1.759037  1.382181  0.228778  0.495277  0.185779 -0.077073
# 3     1.152699 -1.839945 -1.806154 -0.747807 -3.715920  1.522877  0.815902
# 4     0.778789 -3.537429 -1.791214 -1.027710 -1.704642 -1.477825  1.098424
# ...        ...       ...       ...       ...       ...       ...       ...
# 3064 -2.540130  0.782677  0.902258 -0.158354 -0.864670  0.574026 -0.485058
# 3065 -2.664826 -0.293766  1.762221  3.242308 -0.950845  1.887142 -0.002618
# 3066  1.178637 -0.034463  0.919923 -1.328101 -0.946782  2.642062 -0.147244
# 3067  1.063765 -0.437878  0.953383  1.701760  0.205101 -0.106554 -0.463532
# 3068  0.967444 -2.240599 -1.956549 -1.424923 -3.291801 -0.523360 -0.240557
#
#       cluster
# 0           1
# 1           1
# 2           3
# ...

# %%
cluster_profiles = pca_df_7_clust.groupby('cluster').mean()
cluster_profiles
# Out:
#               PC1       PC2       PC3       PC4       PC5       PC6       PC7
# cluster
# 1       -2.799056  0.140983  0.335774  0.060665  0.279531  0.041504 -0.108327
# 2       -0.009406 -2.050363 -2.714207  0.192330 -2.539363 -0.812032  0.788135
# 3        0.939730  0.241699  0.269951 -0.047444  0.264165  0.100527 -0.074757

# %%
loadings = pd.DataFrame(
    pca_7.components_,
    columns=pca_data.columns,
    index=[f'PC{i+1}' for i in range(pca.n_components_)]
)
loadings
# Out:
#         State  Account length  Area code  Number vmail messages  \
# PC1  0.022013       -0.001584   0.005628              -0.566016
# PC2 -0.012936       -0.102473   0.004105               0.025949
# PC3  0.007511        0.036249  -0.042953              -0.040570
# PC4  0.004435        0.060452  -0.013692               0.023008
# PC5  0.020778       -0.090703  -0.057471              -0.014179
# PC6 -0.011655       -0.080586  -0.005194               0.034841
# PC7  0.044376       -0.388576  -0.014423              -0.017814
#
#      Total day calls  Total day charge  Total eve calls  Total eve charge  \
# PC1         0.020788         -0.008279         0.010474         -0.019009
# PC2        -0.255153         -0.231909        -0.211593         -0.090330
# PC3         0.044187         -0.315232         0.094485         -0.138603
# PC4         0.399309         -0.085903        -0.065928         -0.036659
# PC5         0.007253          0.450353        -0.037596          0.238034
# ...

# %%
# Back-mapping PCs to original features
original_feature_contributions = pd.DataFrame(
    np.dot(cluster_profiles.values, loadings.values),
    columns=loadings.columns,
    index=cluster_profiles.index
)
original_feature_contributions
# Out:
#             State  Account length  Area code  Number vmail messages  \
# cluster
# 1       -0.060131        0.019221  -0.045147               1.575155
# 2       -0.001542        0.112878   0.244271               0.060335
# 3        0.020377       -0.022352  -0.019290              -0.536586
#
#          Total day calls  Total day charge  Total eve calls  Total eve charge  \
# cluster
# 1              -0.033482          0.013259        -0.021934          0.057945
# 2               0.104291          0.125411        -0.060399         -0.012029
# 3              -0.003473         -0.022120         0.015866         -0.017731
#
#          Total night calls  Total night charge  ...  International plan(No)  \
# cluster                                         ...
# 1                 0.015340            0.026747  ...                0.311110
# 2                 0.054100           -0.169086  ...               -2.979788
# 3                -0.012767            0.014863  ...                0.315649
# ...

# %%
import matplotlib.pyplot as plt

cluster_features = original_feature_contributions.T
cluster_features.plot(kind='bar', figsize=(12, 8))
plt.title("Feature Contributions by Cluster")
plt.xlabel("Features")
plt.ylabel("Contribution")
plt.legend(title="Clusters")
plt.show()

# %% [markdown]
# ***Interpretation***
#
# The graph shows three distinct clusters based on the contributions of various variables. Cluster 1 consists of customers with high voicemail usage and no international plan, Cluster 2 includes customers with an active international plan and frequent international calls, while Cluster 3 represents dissatisfied customers who frequently contact customer service and are at risk of churn. These results suggest targeted strategies for each group, such as enhancing voicemail services for Cluster 1, offering international plans for Cluster 2, and improving user experience to reduce churn in Cluster 3.

# %% [markdown]
# **<font color=#f39c12 ><h1>
# 🌐 VI-Deployment</p><h1>**
